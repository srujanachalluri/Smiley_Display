# %% [markdown]
# **Python program**:
# ✊

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # TensorFlow Addons: For additional TensorFlow functionalities.

# %%
# !pip install tensorflow

# %%
# !pip install tensorflow-addons
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.3.0
#     Uninstalling typeguard-4.3.0:
#       Successfully uninstalled typeguard-4.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.4.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# ...

# %% [markdown]
# image processing and machine learning. In this example, we'll use the OpenCV library to detect faces and add a smiley emoji to the detected faces in a given image. Here’s a step-by-step guide to help you set up the project.

# %% [markdown]
# You'll need to install OpenCV and NumPy. Run the following code in a code cell:

# %%
# !pip install opencv-python-headless
# !pip install numpy

# %% [markdown]
# import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
uploaded = files.upload()
smiley_path = next(iter(uploaded))
# Out:
#      <input type="file" id="files-8c6bcd65-81dc-4fb0-91c9-9c52d7dda735" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c6bcd65-81dc-4fb0-91c9-9c52d7dda735">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load the smiley image
smiley_image = cv2.imread(smiley_path, cv2.IMREAD_UNCHANGED)

# Convert the image from BGR to RGB (OpenCV uses BGR by default)
smiley_image_rgb = cv2.cvtColor(smiley_image, cv2.COLOR_BGRA2RGBA)  # Use RGBA if the image has transparency

# Display the smiley image
plt.imshow(smiley_image_rgb)
plt.axis('off')  # Hide axes
plt.title("Uploaded Smiley Image")
plt.show()
